# %% [markdown]
# <a href="https://colab.research.google.com/github/segestic/30-Days-Of-React/blob/master/LivePortrait_jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone -b dev https://github.com/camenduru/LivePortrait
# %cd /content/LivePortrait

# !rm -rf /content/LivePortrait/pretrained_weights
# !git clone https://huggingface.co/camenduru/LivePortrait /content/LivePortrait/pretrained_weights

# !pip install tyro==0.8.5 onnxruntime-gpu==1.18.1 onnx==1.16.1 gradio==4.36.1 colorama

# %cd /content/LivePortrait/src/utils/dependencies/insightface/thirdparty/face3d/mesh/cython
# !python setup.py build_ext --inplace
# Out:
# /content
# fatal: destination path 'LivePortrait' already exists and is not an empty directory.
# /content/LivePortrait
# Cloning into '/content/LivePortrait/pretrained_weights'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 19 (delta 0), reused 0 (delta 0), pack-reused 3 (from 1)
# Unpacking objects: 100% (19/19), 3.49 KiB | 713.00 KiB/s, done.
# Filtering content: 100% (8/8), 628.42 MiB | 75.03 MiB/s, done.
# Requirement already satisfied: tyro==0.8.5 in /usr/local/lib/python3.12/dist-packages (0.8.5)
# Requirement already satisfied: onnxruntime-gpu==1.18.1 in /usr/local/lib/python3.12/dist-packages (1.18.1)
# Requirement already satisfied: onnx==1.16.1 in /usr/local/lib/python3.12/dist-packages (1.16.1)
# Requirement already satisfied: gradio==4.36.1 in /usr/local/lib/python3.12/dist-packages (4.36.1)
# Requirement already satisfied: colorama in /usr/local/lib/python3.12/dist-packages (0.4.6)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.12/dist-packages (from tyro==0.8.5) (0.17.0)
# Requirement already satisfied: typing-extensions>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from tyro==0.8.5) (4.14.1)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.12/dist-packages (from tyro==0.8.5) (13.9.4)
# Requirement already satisfied: shtab>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from tyro==0.8.5) (1.7.2)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu==1.18.1) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu==1.18.1) (25.2.10)
# Requirement already satisfied: numpy<2.0,>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu==1.18.1) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu==1.18.1) (25.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu==1.18.1) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu==1.18.1) (1.13.3)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (5.5.0)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (0.116.1)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (0.6.1)
# Requirement already satisfied: gradio-client==1.0.1 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (1.0.1)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (0.34.4)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (6.5.2)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (3.1.6)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (3.10.0)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (3.11.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (2.2.2)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (10.4.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (2.11.7)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (6.0.2)
# Requirement already satisfied: ruff>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (0.12.9)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (0.16.0)
# Requirement already satisfied: urllib3~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (2.5.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio==4.36.1) (0.35.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.0.1->gradio==4.36.1) (2025.3.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.0.1->gradio==4.36.1) (11.0.3)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair<6.0,>=4.2.0->gradio==4.36.1) (4.25.1)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair<6.0,>=4.2.0->gradio==4.36.1) (2.1.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.1->gradio==4.36.1) (4.10.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.1->gradio==4.36.1) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.1->gradio==4.36.1) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.1->gradio==4.36.1) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio==4.36.1) (0.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.19.3->gradio==4.36.1) (3.19.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.19.3->gradio==4.36.1) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.19.3->gradio==4.36.1) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.19.3->gradio==4.36.1) (1.1.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==4.36.1) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==4.36.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==4.36.1) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==4.36.1) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==4.36.1) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.0->gradio==4.36.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio==4.36.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio==4.36.1) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->gradio==4.36.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->gradio==4.36.1) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->gradio==4.36.1) (0.4.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1.0->tyro==0.8.5) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1.0->tyro==0.8.5) (2.19.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio==4.36.1) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio==4.36.1) (1.5.4)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.12/dist-packages (from coloredlogs->onnxruntime-gpu==1.18.1) (10.0)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi->gradio==4.36.1) (0.47.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime-gpu==1.18.1) (1.3.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.36.1) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.36.1) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.36.1) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.36.1) (0.27.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro==0.8.5) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio==4.36.1) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx>=0.24.1->gradio==4.36.1) (1.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.19.3->gradio==4.36.1) (3.4.3)
# /content/LivePortrait/src/utils/dependencies/insightface/thirdparty/face3d/mesh/cython

# %%
# %cd /content/LivePortrait
# !python inference.py -s /content/LivePortrait/assets/examples/source/s7.jpg -d /content/LivePortrait/assets/examples/driving/d7.mp4
# Out:
# /content/LivePortrait
# [06:52:37] Load appearance_feature_extractor done.   ]8;id=635179;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=861530;file:///content/LivePortrait/src/live_portrait_wrapper.py#30\30]8;;\
# [06:52:38] Load motion_extractor done.               ]8;id=992835;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=412896;file:///content/LivePortrait/src/live_portrait_wrapper.py#33\33]8;;\
#            Load warping_module done.                 ]8;id=307403;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=930531;file:///content/LivePortrait/src/live_portrait_wrapper.py#36\36]8;;\
# [06:52:39] Load spade_generator done.                ]8;id=46173;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=53817;file:///content/LivePortrait/src/live_portrait_wrapper.py#39\39]8;;\
#            Load stitching_retargeting_module done.   ]8;id=873042;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=580234;file:///content/LivePortrait/src/live_portrait_wrapper.py#43\43]8;;\
# 2025-08-26 06:52:39.333549686 [E:onnxruntime:Default, provider_bridge_ort.cc:1745 TryGetProviderInfo_CUDA] /onnxruntime_src/onnxruntime/core/session/provider_bridge_ort.cc:1426 onnxruntime::Provider& onnxruntime::ProviderLibrary::Get() [ONNXRuntimeError] : 1 : FAIL : Failed to load library libonnxruntime_providers_cuda.so with error: libcublasLt.so.11: cannot open shared object file: No such file or directory
#
# 2025-08-26 06:52:39.333578378 [W:onnxruntime:Default, onnxruntime_pybind_state.cc:895 CreateExecutionProviderInstance] Failed to create CUDAExecutionProvider. Please reference https://onnxruntime.ai/docs/execution-providers/CUDA-ExecutionProvider.html#requirementsto ensure all dependencies are met.
#            LandmarkRunner warmup time: 0.123s              ]8;id=424719;file:///content/LivePortrait/src/utils/landmark_runner.py\landmark_runner.py]8;;\:]8;id=989834;file:///content/LivePortrait/src/utils/landmark_runner.py#89\89]8;;\
# 2025-08-26 06:52:39.628098963 [E:onnxruntime:Default, provider_bridge_ort.cc:1745 TryGetProviderInfo_CUDA] /onnxruntime_src/onnxruntime/core/session/provider_bridge_ort.cc:1426 onnxruntime::Provider& onnxruntime::ProviderLibrary::Get() [ONNXRuntimeError] : 1 : FAIL : Failed to load library libonnxruntime_providers_cuda.so with error: libcublasLt.so.11: cannot open shared object file: No such file or directory
#
# 2025-08-26 06:52:39.651968374 [E:onnxruntime:Default, provider_bridge_ort.cc:1745 TryGetProviderInfo_CUDA] /onnxruntime_src/onnxruntime/core/session/provider_bridge_ort.cc:1426 onnxruntime::Provider& onnxruntime::ProviderLibrary::Get() [ONNXRuntimeError] : 1 : FAIL : Failed to load library libonnxruntime_providers_cuda.so with error: libcublasLt.so.11: cannot open shared object file: No such file or directory
#
#            FaceAnalysisDIY warmup time: 0.255s           ]8;id=157584;file:///content/LivePortrait/src/utils/face_analysis_diy.py\face_analysis_diy.py]8;;\:]8;id=337790;file:///content/LivePortrait/src/utils/face_analysis_diy.py#79\79]8;;\
#            Load source image from                   ]8;id=681764;file:///content/LivePortrait/src/live_portrait_pipeline.py\live_portrait_pipeline.py]8;;\:]8;id=591373;file:///content/LivePortrait/src/live_portrait_pipeline.py#46\46]8;;\
#            /content/LivePortrait/assets/examples/so
#            urce/s7.jpg
# [06:52:44] Load from video file (mp4 mov avi        ]8;id=277677;file:///content/LivePortrait/src/live_portrait_pipeline.py\live_portrait_pipeline.py]8;;\:]8;id=167899;file:///content/LivePortrait/src/live_portrait_pipeline.py#72\72]8;;\
#            etc...):
#            /content/LivePortrait/assets/examples/dr
#            iving/d7.mp4
# Animating... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:26
# Concatenating result... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:01
# writing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:04
# Dump to animations/s7--d7_concat.mp4
#
# writing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:04
# Dump to animations/s7--d7.mp4

# %%
# !find /content/LivePortrait/ -name "*.mp4"
# Out:
# /content/LivePortrait/assets/examples/driving/d9.mp4
# /content/LivePortrait/assets/examples/driving/d8.mp4
# /content/LivePortrait/assets/examples/driving/d2.mp4
# /content/LivePortrait/assets/examples/driving/d0.mp4
# /content/LivePortrait/assets/examples/driving/d7.mp4
# /content/LivePortrait/assets/examples/driving/d6.mp4
# /content/LivePortrait/assets/examples/driving/d3.mp4
# /content/LivePortrait/assets/examples/driving/d1.mp4
# /content/LivePortrait/assets/examples/driving/d5.mp4
# /content/LivePortrait/animations/s7--d7_concat.mp4
# /content/LivePortrait/animations/s7--d7.mp4

# %%
# !ls -l /content/LivePortrait/animations/s7--d7.mp4
# Out:
# -rw-r--r-- 1 root root 1015333 Aug 26 06:53 /content/LivePortrait/animations/s7--d7.mp4

# %%
from IPython.display import HTML
from base64 import b64encode

# Replace 'video.mp4' with your actual file name
mp4 = open('/content/LivePortrait/animations/s7--d7.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

HTML(f"""
<video width="400" controls>
  <source src="{data_url}" type="video/mp4">
  Your browser does not support the video tag.
</video>
""")
# Out:
# <video width="400" controls>
#   <source src="data:video/mp4;base64,..." type="video/mp4">
#   Your browser does not support the video tag.
# </video>
